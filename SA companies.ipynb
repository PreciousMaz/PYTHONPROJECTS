# %%
import pandas as pd

# %%
df_list = pd.read_html('https://en.wikipedia.org/wiki/List_of_largest_companies_in_South_Africa',match='Industry')

# %%
df_list
# Out:
# [    Unnamed: 0  Forbes 2000 rank                Name   Headquarters  \
#  0            1               261      Anglo American  Johannesburg*
#  1            2               415       Standard Bank   Johannesburg
#  2            3               418             Naspers      Cape Town
#  3            4               445          First Rand   Johannesburg
#  4            5               530               Sasol   Johannesburg
#  5            6               661  Absa Group Limited   Johannesburg
#  6            7               755             Nedbank   Johannesburg
#  7            8               782          Old Mutual        Sandton
#  8            9               818              Sanlam      Bellville
#  9           10               936           MTN Group   Johannesburg
#  10          11              1764            Investec   Johannesburg
#  11          12              1764        RMB Holdings   Johannesburg
#  12          13              1881   Shoprite Holdings    Brackenfell
# ...

# %%
len(df_list)
# Out:
# 1

# %%
df = df_list[0]

# %%
df
# Out:
#     Unnamed: 0  Forbes 2000 rank                Name   Headquarters  \
# 0            1               261      Anglo American  Johannesburg*
# 1            2               415       Standard Bank   Johannesburg
# 2            3               418             Naspers      Cape Town
# 3            4               445          First Rand   Johannesburg
# 4            5               530               Sasol   Johannesburg
# 5            6               661  Absa Group Limited   Johannesburg
# 6            7               755             Nedbank   Johannesburg
# 7            8               782          Old Mutual        Sandton
# 8            9               818              Sanlam      Bellville
# 9           10               936           MTN Group   Johannesburg
# 10          11              1764            Investec   Johannesburg
# 11          12              1764        RMB Holdings   Johannesburg
# 12          13              1881   Shoprite Holdings    Brackenfell
# ...

# %%
df.to_csv('SACompanies.csv' , index = 'false')
